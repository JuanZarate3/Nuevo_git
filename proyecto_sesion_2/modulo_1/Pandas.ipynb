# %% [markdown]
# ## Tarea 4

# %%
import pandas as pd
# Out:
# /var/folders/yk/13j8tl_55psfgsq3k20pxr500000gp/T/ipykernel_5722/1915490065.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Data Frame

# %%
rocas = pd.Series(['Esquisto', 'Granito', 'Arenisca', 'Depósito'], index=['Metamórfica', 'ïgnea', 'Sedimentaria', 'No consolidado'] )

# %%
rocas
# Out:
# Metamórfica       Esquisto
# ïgnea              Granito
# Sedimentaria      Arenisca
# No consolidado    Depósito
# dtype: object

# %% [markdown]
# ## Dataframe

# %%
#Vamos a crear un diccionario y apartir de él, un dataframe:

rocas_dict = {'Roca':['Esquisto' ,'Granito', 'Arenisca', 'Depósito'], 'Tipo': ['Metamórfica', 'ïgnea', 'Sedimentaria', 'No consolidado'], 'Densidad': ['2.7','2.6', '2.4','2.0']}

# %%
type(rocas_dict)
# Out:
# dict

# %%
rocas_df = pd.DataFrame(rocas_dict, index=[1, 2, 3, 4])

# %%
rocas_df
# Out:
#        Roca            Tipo Densidad
# 1  Esquisto     Metamórfica      2.7
# 2   Granito           ïgnea      2.6
# 3  Arenisca    Sedimentaria      2.4
# 4  Depósito  No consolidado      2.0

# %% [markdown]
# ## Leer Dataframe externos:

# %%
df_best = pd.read_csv('datos/Volcanes_col.csv', sep= ',', header=0)

# %%
df_best
# Out:
#             X         Y  OBJECTID  VolcanID          NombreVolcan  \
# 0  -76.214977  1.916518         1       NaN                   NaN
# 1  -76.166495  2.232286         2       NaN  Volcan Santa Leticia
# 2  -76.082576  2.179546         3       NaN      Volcán El Pensil
# 3  -76.217778  2.110280         4       NaN      Volcán El Dorado
# 4  -76.477694  2.240949         5       NaN    Maar de Yerbabuena
# ..        ...       ...       ...       ...                   ...
# 56 -77.252273  1.103001        73       NaN                   NaN
# 57 -77.316687  1.108989        74       NaN                   NaN
# 58 -75.047612  5.514637        75       NaN   Volcán El Escondido
# 59 -74.960051  5.649027        78       NaN      Volcán San Diego
# 60 -75.364000  5.206000        79       NaN        Volcán Romeral
#
#     AlturaSobreNivelMar           Latitud           Longitud  \
# 0                1800.0  1° 54' 59,465" N  76° 12' 53,917" W
# ...

# %%
#traer los primeros diez registros:

df_best.head(10)
# Out:
#            X         Y  OBJECTID  VolcanID            NombreVolcan  \
# 0 -76.214977  1.916518         1       NaN                     NaN
# 1 -76.166495  2.232286         2       NaN    Volcan Santa Leticia
# 2 -76.082576  2.179546         3       NaN        Volcán El Pensil
# 3 -76.217778  2.110280         4       NaN        Volcán El Dorado
# 4 -76.477694  2.240949         5       NaN      Maar de Yerbabuena
# 5 -76.429751  2.183601         6       NaN  Volcán Laguna del Buey
# 6 -75.919384  1.757209         7       NaN                     NaN
# 7 -75.968107  2.302637         8       NaN         Volcán La Palma
# 8 -76.823181  1.488240        10       NaN       Volcán Las Ánimas
# 9 -77.716683  1.084583        11       NaN          Volcán Azufral
#
#    AlturaSobreNivelMar           Latitud           Longitud  \
# 0               1800.0  1° 54' 59,465" N  76° 12' 53,917" W
# 1                  NaN  2° 13' 56,229" N   76° 9' 59,382" W
# ...

# %%
# traer los últimos diez registros


df_best.tail(10)
# Out:
#             X         Y  OBJECTID  VolcanID         NombreVolcan  \
# 51 -76.036683  2.189537        68       NaN      Volcán El Morro
# 52 -77.012961  1.116313        69       NaN      Volcán Sibundoy
# 53 -76.204729  1.921142        70       NaN                  NaN
# 54 -76.176280  1.174334        71       NaN
# 55 -77.066665  1.054284        72       NaN                  NaN
# 56 -77.252273  1.103001        73       NaN                  NaN
# 57 -77.316687  1.108989        74       NaN                  NaN
# 58 -75.047612  5.514637        75       NaN  Volcán El Escondido
# 59 -74.960051  5.649027        78       NaN     Volcán San Diego
# 60 -75.364000  5.206000        79       NaN       Volcán Romeral
#
#     AlturaSobreNivelMar           Latitud           Longitud  \
# 51               1700.0  2° 11' 22,334" N   76° 2' 12,057" W
# 52                  NaN   1° 6' 58,725" N   77° 0' 46,661" W
# 53               1800.0  1° 55' 16,110" N  76° 12' 17,026" W
# ...

# %%
# Identificar los valores nulos. Para visualizar los datos nulos usamos:
df_best.isnull()
#aquellos valores que son True, son los valores nulos o faltantes. En cambio, los valores False, 
# son aquellos datos que sí tienen cierto valor
# Out:
#         X      Y  OBJECTID  VolcanID  NombreVolcan  AlturaSobreNivelMar  \
# 0   False  False     False      True          True                False
# 1   False  False     False      True         False                 True
# 2   False  False     False      True         False                False
# 3   False  False     False      True         False                False
# 4   False  False     False      True         False                False
# ..    ...    ...       ...       ...           ...                  ...
# 56  False  False     False      True          True                 True
# 57  False  False     False      True          True                 True
# 58  False  False     False      True         False                False
# 59  False  False     False      True         False                False
# 60  False  False     False      True         False                False
#
#     Latitud  Longitud  Comentarios    URL  GlobalID
# ...

# %%
# me interesa la información sobre la altura de los volcanes desde el nivel del mar.
# por tal motivo voy a traer solo la columna '"alturasobreniveldelmar". De allí vamos a hacer 
# alguna estadística:
Altura_mar = df_best.iloc[:, 5:6]
Altura_mar
# Out:
#     AlturaSobreNivelMar
# 0                1800.0
# 1                   NaN
# 2                2200.0
# 3                2000.0
# 4                3100.0
# ..                  ...
# 56                  NaN
# 57                  NaN
# 58               1700.0
# 59                850.0
# 60               3858.0
#
# [61 rows x 1 columns]

# %%
# vamos a sacarle las estadísticas a esta columna:
estadisticas = Altura_mar.describe()
print(estadisticas)
# Out:
#        AlturaSobreNivelMar
# count            57.000000
# mean           3358.438596
# std            1301.229282
# min             500.000000
# 25%            2200.000000
# 50%            3500.000000
# 75%            4420.000000
# max            5364.000000

# %%
# Calcular la media
media = Altura_mar.mean()
print("Media:", media)

# Calcular la mediana
mediana = Altura_mar.median()
print("Mediana:", mediana)

# Calcular la desviación estándar
desviacion_estandar = Altura_mar.std()
print("Desviación estándar:", desviacion_estandar)
# Out:
# Media: AlturaSobreNivelMar    3358.438596
# dtype: float64
# Mediana: AlturaSobreNivelMar    3500.0
# dtype: float64
# Desviación estándar: AlturaSobreNivelMar    1301.229282
# dtype: float64

# %%
#Generar una visualización que muestre las principales medidas estadísticas de la columna.


import matplotlib.pyplot as plt

# Calcular las principales medidas estadísticas de cada columna
estadisticas = df_best.describe()

# Transponer el DataFrame para que las columnas se conviertan en filas y viceversa
estadisticas = estadisticas.T

# Crear un diagrama de caja para visualizar las principales medidas estadísticas de cada columna
estadisticas.plot(kind='box', vert=False, figsize=(10,6), patch_artist=True)

# Añadir título y etiquetas
plt.title('Diagrama de Caja de las Principales Medidas Estadísticas')
plt.xlabel('Valor')

# Mostrar el diagrama de caja
plt.show()
